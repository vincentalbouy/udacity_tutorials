# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'originated', 'of', 'term', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.235476
# Nearest to from: adjustment, amphisbaena, hak, haram, deteriorate, marcellus, orator, lefty,
# Nearest to when: divination, argyll, lexicon, pentagon, mellon, mulder, dana, parcels,
# Nearest to world: drew, henderson, kashubians, camcorder, subseteq, disbandment, mua, pound,
# Nearest to UNK: preventive, point, dismantled, pavlov, startling, gubernatorial, tashfin, phosphide,
# Nearest to people: strachey, enabling, corresponded, novarum, architecture, polygamy, ventricles, sven,
# Nearest to most: fixation, diagonally, thymine, vanity, earthbound, ser, uncovered, suebi,
# Nearest to not: kicker, turkmen, explicated, jester, ushering, producer, illegitimacy, believe,
# Nearest to be: peat, stockpiling, harpist, stewards, lotharingia, demo, mellow, georgy,
# Nearest to b: aquarii, desktop, draco, haze, sergius, fatalism, bnetd, tramways,
# Nearest to state: retro, monasteries, belongings, trill, points, socialite, positional, plagiarism,
# Nearest to on: swords, pickup, debates, beacons, novelty, sail, continuance, emery,
# Nearest to three: cadmium, pregnancies, yuga, lavrenty, divx, workmanship, tip, hematite,
# Nearest to he: niebuhr, mariners, mazovia, yam, sailboat, scrambling, upwelling, dido,
# Nearest to one: bitnet, rouse, bucaram, comforts, feyerabend, variadic, mjd, chronica,
# Nearest to history: gamemaster, deed, ltcm, kombat, undefended, manner, salaam, touches,
# Nearest to up: merz, porvoo, pk, eukaryotes, hovering, learning, ancyra, criminal,
# Average loss at step 2000: 4.373872
# Average loss at step 4000: 3.866357
# Average loss at step 6000: 3.786631
# Average loss at step 8000: 3.688730
# Average loss at step 10000: 3.623239
# Nearest to from: in, coincidence, handfasting, by, on, maynooth, of, amnesty,
# Nearest to when: argyll, beetles, before, had, mulder, lengthened, bucky, hammer,
# Nearest to world: subseteq, drew, gamblers, henderson, largest, rallies, clermont, jenner,
# Nearest to UNK: universelle, requirement, painter, cooling, h, defected, nun, intro,
# Nearest to people: sped, strachey, herrera, ie, bagdad, uncivilized, batted, dostum,
# Nearest to most: diagonally, skilled, invades, listening, varese, thymine, optically, jc,
# Nearest to not: they, to, it, also, turkmen, kicker, spreading, shui,
# Nearest to be: have, was, by, become, languedoc, memetic, is, been,
# Nearest to b: d, draco, haze, desktop, texaco, peppermint, solicit, asgard,
# Nearest to state: points, groundwork, boulders, retro, soviet, holmium, encouragement, socialite,
# Nearest to on: in, pickup, upon, from, ho, yearning, mixed, by,
# Nearest to three: five, six, four, eight, seven, two, nine, zero,
# Nearest to he: it, they, she, who, fannish, transduction, hashemite, pleadings,
# Nearest to one: two, three, four, seven, six, eight, five, foxy,
# Nearest to history: conversely, resume, scattered, lamm, groundwork, conical, kombat, minutes,
# Nearest to up: merz, hovering, pk, maritime, porvoo, payroll, madeline, him,
# Average loss at step 12000: 3.605670
# Average loss at step 14000: 3.573538
# Average loss at step 16000: 3.408158
# Average loss at step 18000: 3.459539
# Average loss at step 20000: 3.541876
# Nearest to from: in, into, at, philosophic, under, for, and, on,
# Nearest to when: before, if, after, was, during, ji, lengthened, beetles,
# Nearest to world: subseteq, gamblers, drew, city, clermont, capsule, rallies, largest,
# Nearest to UNK: ralston, lepers, xxx, manzarek, artist, defected, smokey, fluorine,
# Nearest to people: times, batted, vladislav, uncivilized, vitally, rtiges, herrera, strachey,
# Nearest to most: more, some, skilled, varese, invades, jc, kind, posthumous,
# Nearest to not: also, they, it, kicker, usually, probably, now, to,
# Nearest to be: have, been, by, become, was, is, languedoc, eamon,
# Nearest to b: d, draco, global, suspending, vindicated, baum, infocom, senses,
# Nearest to state: points, frontier, monasteries, retro, boulders, soviet, phonology, gentile,
# Nearest to on: upon, in, at, gadolinium, through, pickup, teacher, from,
# Nearest to three: four, six, five, two, seven, eight, zero, nine,
# Nearest to he: it, she, they, who, there, fannish, then, never,
# Nearest to one: three, two, seven, four, six, eight, five, nine,
# Nearest to history: resume, conical, scattered, conversely, lublin, apollo, minutes, character,
# Nearest to up: him, merz, them, payroll, hovering, learning, madeline, porvoo,
# Average loss at step 22000: 3.507341
# Average loss at step 24000: 3.488222
# Average loss at step 26000: 3.482367
# Average loss at step 28000: 3.485444
# Average loss at step 30000: 3.506264
# Nearest to from: into, under, in, coincidence, through, after, amnesty, on,
# Nearest to when: if, before, after, where, had, during, with, was,
# Nearest to world: subseteq, largest, gamblers, rallies, bbn, founding, mothra, crankshaft,
# Nearest to UNK: h, lepers, westwood, others, defected, churchman, centrosomes, canons,
# Nearest to people: times, herrera, days, printf, vitally, vladislav, encountered, heth,
# Nearest to most: more, some, many, jc, varese, posthumous, invades, kind,
# Nearest to not: still, they, there, it, kicker, drawn, cylinders, probably,
# Nearest to be: been, have, become, is, languedoc, are, was, remy,
# Nearest to b: d, player, global, vindicated, suspending, saddam, draco, burzum,
# Nearest to state: points, soviet, phonology, monasteries, patterns, seventeenth, boulders, gentile,
# Nearest to on: upon, in, ho, through, into, zebra, overwhelming, at,
# Nearest to three: four, five, seven, eight, six, two, nine, zero,
# Nearest to he: she, it, they, who, there, never, summoned, abusive,
# Nearest to one: two, seven, four, three, eight, five, six, nine,
# Nearest to history: resume, conical, character, groundwork, scattered, conversely, excelled, apollo,
# Nearest to up: him, them, hovering, out, merz, learning, jacks, off,
# Average loss at step 32000: 3.505136
# Average loss at step 34000: 3.493956
# Average loss at step 36000: 3.449962
# Average loss at step 38000: 3.303371
# Average loss at step 40000: 3.433561
# Nearest to from: coincidence, in, under, through, of, maynooth, neanderthal, philosophic,
# Nearest to when: if, before, where, while, after, during, was, husky,
# Nearest to world: arabians, capsule, mothra, tb, subseteq, ghidorah, gamblers, clermont,
# Nearest to UNK: nicholas, b, icrm, polyphyletic, habitus, scriptural, photon, fitzroy,
# Nearest to people: printf, encountered, vitally, others, hahn, myrna, gustav, tangier,
# Nearest to most: more, some, rubenstein, many, posthumous, varese, among, cloudbusting,
# Nearest to not: still, they, now, never, drawn, also, uncensored, celled,
# Nearest to be: been, have, become, being, is, was, cohomology, refer,
# Nearest to b: d, c, UNK, m, kharkov, burzum, khazaria, interviews,
# Nearest to state: gentile, points, patterns, government, sorcerers, soviet, citizen, boulders,
# Nearest to on: upon, during, ho, in, at, between, within, windmills,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to he: she, it, they, there, who, never, then, i,
# Nearest to one: seven, six, four, two, five, eight, three, nine,
# Nearest to history: conical, list, lublin, scattered, conversely, conflicting, resume, names,
# Nearest to up: him, them, out, off, hovering, over, jacks, into,
# Average loss at step 42000: 3.438379
# Average loss at step 44000: 3.453536
# Average loss at step 46000: 3.448234
# Average loss at step 48000: 3.356044
# Average loss at step 50000: 3.384180
# Nearest to from: into, through, under, coincidence, in, on, vipers, maynooth,
# Nearest to when: if, before, after, where, while, during, because, however,
# Nearest to world: largest, mothra, capsule, pirin, overlooking, subseteq, firestorm, ghidorah,
# Nearest to UNK: kryptonite, pluriform, douglas, squandered, macrocosm, termites, codecs, edison,
# Nearest to people: vitally, gaels, printf, children, encountered, genealogists, others, festivities,
# Nearest to most: more, some, rubenstein, cloudbusting, among, many, particularly, tilting,
# Nearest to not: now, still, never, piotr, turkmen, they, cylinders, usually,
# Nearest to be: have, was, been, become, being, were, is, sire,
# Nearest to b: d, c, m, khazaria, cjd, tack, r, kharkov,
# Nearest to state: sorcerers, citizen, boulders, phonology, abijah, patterns, intercontinental, cumings,
# Nearest to on: upon, in, under, through, ho, into, throughout, from,
# Nearest to three: six, four, seven, five, eight, nine, two, zero,
# Nearest to he: she, it, they, there, who, we, then, instruct,
# Nearest to one: six, two, seven, four, eight, five, three, nine,
# Nearest to history: list, conflicting, champion, acoustic, conical, lublin, apollo, consists,
# Nearest to up: out, them, him, off, down, into, away, hovering,
# Average loss at step 52000: 3.440726
# Average loss at step 54000: 3.425964
# Average loss at step 56000: 3.437448
# Average loss at step 58000: 3.396201
# Average loss at step 60000: 3.395930
# Nearest to from: through, into, coincidence, under, philosophic, in, biographical, maynooth,
# Nearest to when: if, before, while, where, after, although, because, during,
# Nearest to world: largest, gamblers, cold, civil, national, subseteq, mothra, mystery,
# Nearest to UNK: beads, copulation, qaeda, ortelius, agave, plotting, forwarding, oblast,
# Nearest to people: vitally, children, others, species, men, americans, langton, writers,
# Nearest to most: some, more, many, among, particularly, rubenstein, annihilation, use,
# Nearest to not: still, now, you, cylinders, drawn, usually, they, telephus,
# Nearest to be: been, become, was, have, languedoc, refer, is, being,
# Nearest to b: d, m, c, r, cartilaginous, khazaria, tack, x,
# Nearest to state: government, sorcerers, soviet, residence, abijah, states, points, city,
# Nearest to on: upon, in, through, privates, pickup, noord, greve, analytical,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to he: she, it, they, there, who, we, gunboats, never,
# Nearest to one: two, four, six, seven, eight, five, three, nine,
# Nearest to history: list, geography, politics, consists, tradition, alistair, conflicting, sisterhood,
# Nearest to up: out, off, them, him, away, down, jacks, hovering,
# Average loss at step 62000: 3.241888
# Average loss at step 64000: 3.256363
# Average loss at step 66000: 3.403998
# Average loss at step 68000: 3.395493
# Average loss at step 70000: 3.358270
# Nearest to from: through, into, coincidence, under, between, in, within, for,
# Nearest to when: if, before, while, where, after, because, though, although,
# Nearest to world: gamblers, cold, largest, capsule, winter, bonanza, pirin, cassatt,
# Nearest to UNK: vhdl, hassan, aptly, levellers, appleseed, beaulieu, ralston, largo,
# Nearest to people: children, vitally, women, others, species, men, citizens, americans,
# Nearest to most: more, many, some, particularly, annihilation, cloudbusting, especially, very,
# Nearest to not: still, now, usually, never, cylinders, generally, montag, uncensored,
# Nearest to be: been, become, is, being, are, have, was, were,
# Nearest to b: d, c, r, f, m, khazaria, ordain, namespace,
# Nearest to state: government, states, city, frontier, sorcerers, antitrust, citizen, queue,
# Nearest to on: upon, in, through, via, privates, supercar, windmills, pickup,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to he: she, it, they, there, we, never, who, summoned,
# Nearest to one: six, two, seven, four, eight, five, three, nine,
# Nearest to history: list, geography, metropolitan, consists, bnetd, conflicting, camden, resume,
# Nearest to up: off, out, them, him, down, away, back, unchallenged,
# Average loss at step 72000: 3.372203
# Average loss at step 74000: 3.345992
# Average loss at step 76000: 3.316952
# Average loss at step 78000: 3.351947
# Average loss at step 80000: 3.379775
# Nearest to from: through, into, in, within, after, under, coincidence, between,
# Nearest to when: if, before, after, during, while, though, because, where,
# Nearest to world: cold, gamblers, pirin, mothra, sykes, capsule, largest, pastime,
# Nearest to UNK: dr, cj, sir, physicist, http, restaurants, ystok, clearances,
# Nearest to people: children, women, men, species, vitally, things, citizens, those,
# Nearest to most: more, some, particularly, many, annihilation, especially, among, cloudbusting,
# Nearest to not: still, generally, usually, never, cylinders, now, it, always,
# Nearest to be: been, become, have, being, refer, languedoc, germain, get,
# Nearest to b: d, c, khazaria, m, f, r, digitalis, cjd,
# Nearest to state: city, government, frontier, states, sorcerers, citizen, queue, abijah,
# Nearest to on: upon, through, in, at, pickup, via, upheaval, zebra,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to he: she, it, they, there, who, we, never, eventually,
# Nearest to one: seven, six, two, eight, three, four, five, nine,
# Nearest to history: list, geography, membered, grue, administration, because, title, bishop,
# Nearest to up: out, off, them, him, down, away, back, commedia,
# Average loss at step 82000: 3.409237
# Average loss at step 84000: 3.409260
# Average loss at step 86000: 3.390559
# Average loss at step 88000: 3.352809
# Average loss at step 90000: 3.366044
# Nearest to from: through, into, under, in, across, coincidence, before, on,
# Nearest to when: before, if, while, after, where, although, because, until,
# Nearest to world: pirin, cold, winter, capsule, cassatt, semicircular, gamblers, mothra,
# Nearest to UNK: http, et, scavenging, bhp, repayment, criticizing, assigning, diasporas,
# Nearest to people: children, women, men, americans, those, vitally, person, jews,
# Nearest to most: more, some, many, particularly, among, especially, annihilation, use,
# Nearest to not: still, reconquista, nor, also, never, generally, now, we,
# Nearest to be: been, become, refer, was, have, being, get, is,
# Nearest to b: d, c, r, f, m, khazaria, q, ordain,
# Nearest to state: government, city, frontier, states, queue, sorcerers, citizen, chubut,
# Nearest to on: upon, at, under, through, pickup, in, from, librivox,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to he: she, it, they, there, who, later, we, eventually,
# Nearest to one: seven, eight, four, two, six, three, five, nine,
# Nearest to history: list, geography, tradition, metropolitan, nicaea, bishop, administration, grue,
# Nearest to up: off, out, them, him, down, away, back, unchallenged,
# Average loss at step 92000: 3.399899
# Average loss at step 94000: 3.254401
# Average loss at step 96000: 3.359535
# Average loss at step 98000: 3.245721
# Average loss at step 100000: 3.359387
# Nearest to from: through, into, in, philosophic, catalyzed, within, diefenbaker, coincidence,
# Nearest to when: if, while, before, although, after, where, during, because,
# Nearest to world: pirin, winter, capsule, cold, aquatic, panes, mothra, cassatt,
# Nearest to UNK: webelements, bernardino, capp, repayment, rightness, staten, dough, manzarek,
# Nearest to people: children, women, men, americans, citizens, letters, students, jews,
# Nearest to most: more, particularly, especially, less, some, among, annihilation, use,
# Nearest to not: never, still, now, generally, nor, they, almost, reconquista,
# Nearest to be: been, have, refer, being, get, become, is, are,
# Nearest to b: d, c, gordon, hammered, khazaria, john, coli, extraterrestrials,
# Nearest to state: government, city, antitrust, frontier, queue, states, citizen, abijah,
# Nearest to on: upon, through, in, at, beneath, via, within, into,
# Nearest to three: five, four, six, seven, two, eight, nine, zero,
# Nearest to he: she, it, they, there, we, who, summoned, never,
# Nearest to one: two, seven, four, five, eight, six, three, nine,
# Nearest to history: list, geography, metropolitan, bnetd, culture, nicaea, phosphide, maynooth,
# Nearest to up: off, out, them, him, down, back, away, together,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
ef plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
